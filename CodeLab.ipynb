# %%
import sys
sys.version
# Out:
# '3.8.10 (tags/v3.8.10:3d8993a, May  3 2021, 11:48:03) [MSC v.1928 64 bit (AMD64)]'

# %%
from enum import Enum

import news_get_data_NUTS
import yhoo_external_raw_factors
import yhoo_history_stock
from LogRoot.Logging import Logger

import pandas as pd

class Option_Historical(Enum):
    YEARS_3 = 1
    MONTH_3 = 2

stockId = 'MELI'
opion = Option_Historical.MONTH_3

#TODO news news_get_data_NUTS.get_json_news_sentimet(stockId)


yhoo_history_stock.get_json_stock_values_history(stockId, Option_Historical.MONTH_3, get_technical_data = True, prepost=False, interval="15m")
df_his = pd.read_csv("d_price/" + stockId + "_stock_history_"+str(opion.name)+".csv", sep='\t')

yhoo_external_raw_factors.get_raw_stocks_values(opion)
df_ext = pd.read_csv("d_external_factors/external_factors_hist_" + str(opion.name) + ".csv", sep='\t')


print("Fin")
# Out:
# matplotlib - [DEBUG] - wrapper() - matplotlib data path: c:\users\leci\appdata\local\programs\python\python38\lib\site-packages\matplotlib\mpl-data
# matplotlib - [DEBUG] - wrapper() - CONFIGDIR=C:\Users\leci\.matplotlib
# matplotlib - [DEBUG] - <module>() - interactive is False
# matplotlib - [DEBUG] - <module>() - platform is win32
# ...
